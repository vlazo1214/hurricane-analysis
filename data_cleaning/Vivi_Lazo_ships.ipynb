# %% [markdown]
# # Data cleaning and preprocessing

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.ensemble import RandomForestRegressor

STATE = 42

# %%
hurricanes = pd.read_csv("../ships/final_clean.csv") # renamed kaggle csv from storms to hurricane_data

# %% [markdown]
# ## Check df info

# %%
hurricanes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4159 entries, 0 to 4158
# Data columns (total 25 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   name                          4159 non-null   object
#  1   year                          4159 non-null   int64
#  2   month                         4159 non-null   int64
#  3   day                           4159 non-null   int64
#  4   hour                          4159 non-null   int64
#  5   lat                           4159 non-null   float64
#  6   long                          4159 non-null   float64
#  7   status                        4159 non-null   object
#  8   category                      4159 non-null   float64
#  9   wind                          4159 non-null   int64
#  10  pressure                      4159 non-null   int64
#  11  tropicalstorm_force_diameter  4159 non-null   int64
# ...

# %%
print(f"Size of entire dataset: {len(hurricanes)}, number of rows without missing: {len(hurricanes.dropna())}, difference: {len(hurricanes) - len(hurricanes.dropna())}")
# Out:
# Size of entire dataset: 4159, number of rows without missing: 3883, difference: 276

# %% [markdown]
# Almost every row does not have a missing value, we will now inspect what columns have missing data

# %%
# find out how much missing data is in each column
for col in hurricanes.columns:
    print(col + ": ", len(hurricanes) - len(hurricanes.dropna(subset=[col])))
# Out:
# name:  0
# year:  0
# month:  0
# day:  0
# hour:  0
# lat:  0
# long:  0
# status:  0
# category:  0
# wind:  0
# pressure:  0
# tropicalstorm_force_diameter:  0
# hurricane_force_diameter:  0
# hurricane_class:  0
# merge_name:  0
# storm_id:  0
# correct_datetime:  0
# datetime:  0
# CSST:  0
# COHC:  0
# SHRD:  134
# RHMD:  134
# MTPW:  0
# VMPI:  134
# DTL:  150

# %% [markdown]
# Because the missing data is from four different columns and only make up ~%6 of the data, these rows will be dropped.

# %%
hurricanes = hurricanes.dropna()

# %%
# ensure df is fully clean 
len(hurricanes) == len(hurricanes.dropna())
# Out:
# True

# %% [markdown]
# ## Check for duplicate values

# %%
hurricanes.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4154    False
# 4155    False
# 4156    False
# 4157    False
# 4158    False
# Length: 3883, dtype: bool

# %% [markdown]
# We can see that there are no duplicate values after running the `duplicated` function.

# %%
# write df to csv
hurricanes.to_csv('../data/cleaned_hurricanes.csv', index=False)

# %%
# split into training and testing
train_df, test_df = train_test_split(hurricanes, test_size=0.2, random_state=STATE)

train_df.to_csv('../data/final_train.csv', index=False)
test_df.to_csv('../data/final_test.csv', index=False)
